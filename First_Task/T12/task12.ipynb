# %%
values = [1, 2, 3, 4]
probability = [1/4, 1/4, 1/6, 1/3]

for n1 in range(3):
    for n2 in range(3):
        for n3 in range(3):
            if n1 + n2 + n3 > 2:
                continue
            p = ((1/4)**n1)*((1/4)**n2)*((1/6)**n3)*((1/3)**(2-n1-n2-n3))
            l = ((1/4)**2) / p
            print(f"({n1}, {n2}, {n3}, {2-n1-n2-n3}), l : {l}, p : {p}")
# Out:
# (0, 0, 0, 2), l : 0.5625, p : 0.1111111111111111
# (0, 0, 1, 1), l : 1.125, p : 0.05555555555555555
# (0, 0, 2, 0), l : 2.25, p : 0.027777777777777776
# (0, 1, 0, 1), l : 0.75, p : 0.08333333333333333
# (0, 1, 1, 0), l : 1.5, p : 0.041666666666666664
# (0, 2, 0, 0), l : 1.0, p : 0.0625
# (1, 0, 0, 1), l : 0.75, p : 0.08333333333333333
# (1, 0, 1, 0), l : 1.5, p : 0.041666666666666664
# (1, 1, 0, 0), l : 1.0, p : 0.0625
# (2, 0, 0, 0), l : 1.0, p : 0.0625
