# %%
import work_functions

# %% [markdown]
# ## Генерация выборки
# ![SampleGeneration.PNG](attachment:SampleGeneration.PNG)

# %%
sample = work_functions.sample_from_exp_distribution(25)
print(sample)
# Out:
# [0.10211474 0.40632788 2.54290272 3.49346938 0.40060787 0.13328955
#  1.12642193 1.55733905 0.55289436 0.14341494 1.54857809 0.22545668
#  2.11616211 0.31655311 0.93010468 3.24741523 0.13880851 1.21006784
#  0.69544005 0.91642591 3.2597405  1.18278308 0.94265648 0.37711803
#  0.54981967]

# %% [markdown]
# ## Мода, медиана, размах, коэффициент ассиметрии

# %%
mode, median, sample_range, asm_coefficient = work_functions.sample_information(sample)
# Out:
# Все элементы выборки разные, все являются модами
# Медиана: 0.9164259064274501
# Размах: 3.3913546431523534
# Коэффициент асимметрии (оценка): 1.119458627926059

# %% [markdown]
# ## Эмперическая функция распределения

# %%
work_functions.empirical_distribution_function_plot(sample)

# %% [markdown]
# ## Гистограмма

# %%
work_functions.histogram(sample)

# %% [markdown]
# ## Boxplot

# %%
work_functions.boxplot(sample)

# %% [markdown]
# ## Сравнение среднего арифметического оценённого с помощью ЦПТ и bootstrap

# %%
work_functions.compare_mean_cpt_bootstrap(sample, 1000000)

# %% [markdown]
# ## Бутстраповская оценка плотности распределения коэффициента асимметрии. Оценка вероятности того, что коэффициент асимметрии будет меньше 1

# %%
work_functions.bootstrap_asm_coefficient_hist(sample, 1000000)
# Out:
# Вероятность того, что коэффициент асимметрии < 1: 0.403669

# %% [markdown]
# ## Сравнение плотности распределения медианы выборки с бутстраповской оценкой этой плотности

# %% [markdown]
# Плотность распределения k-й статистики имеет формулу
# ![image.png](attachment:image.png)

# %%
work_functions.compare_bootstrap_median(sample, 1000000)
